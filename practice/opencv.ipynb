# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('F:\\dataScience\\images\\flower.JPG ')
rgb_image=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gray_scale=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

print(img.shape)

croped_image=rgb_image[500:3500,1000:5000,:]

#plt.imshow(gray_scale)
# Out:
# (4000, 6000, 3)

# %%
croped_image.shape

croped_image=cv2.resize(croped_image,(300,300))
plt.imshow(croped_image)
plt.title("Flower"+str(croped_image.shape))
plt.axis('off')
# Out:
# (-0.5, 299.5, 299.5, -0.5)
